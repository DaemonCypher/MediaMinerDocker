# %%
# !pip install "yt-dlp[default,curl-cffi]"

# %%
# Best available audio download (executable block)
from yt_dlp import YoutubeDL
import os


def download_best_audio(url: str, output_dir: str) -> str:
    os.makedirs(output_dir, exist_ok=True)
    ydl_opts = {
        "format": "bestaudio/best",
        "outtmpl": os.path.join(output_dir, "%(title)s.%(ext)s"),
        "noplaylist": True,
        "quiet": False,
    }
    with YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=True)
        return ydl.prepare_filename(info)


# Prompt for a URL and run
url = ""
if not url:
    raise ValueError("A URL is required.")

output_dir = os.path.join(os.getcwd(), "downloads")
file_path = download_best_audio(url, output_dir)
print(f"Downloaded audio: {file_path}")

# %%
# Best available single-file video download (executable block)
from fastapi.datastructures import URL
from yt_dlp import YoutubeDL
import os


def download_best_video(url: str, output_dir: str) -> str:
    os.makedirs(output_dir, exist_ok=True)
    ydl_opts = {
        "format": "best[ext=mp4]/best",
        "outtmpl": os.path.join(output_dir, "%(title)s.%(ext)s"),
        "noplaylist": True,
        "quiet": False,
    }
    with YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=True)
        return ydl.prepare_filename(info)


# Prompt for a URL and run
url = ""
if not url:
    raise ValueError("A URL is required.")

output_dir = os.path.join(os.getcwd(), "downloads")
file_path = download_best_video(url, output_dir)
print(f"Downloaded video: {file_path}")
